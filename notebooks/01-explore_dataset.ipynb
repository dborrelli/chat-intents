# %% [markdown]
# # Chat intents
#
# ## Initial Data Exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import re
import nltk
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize
from nltk.tokenize import WhitespaceTokenizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)
pd.set_option("max_colwidth", 400)

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /Users/dave/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/dave/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/dave/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ### Load data

# %%
data_full = pd.read_csv('../data/raw/train.csv')
data_full.sample(10)
# Out:
#                                                                                      text  \
# 9473                                     What was the extra charge for withdrawing money?
# 8849  Please help me figure out the reason for the odd withdrawal amount from my account?
# 2397                         I think something went wrong, I didn't get the right amount.
# 4274                         My wallet isn't showing my top-up, did I do something wrong?
# 8399                                                  How about disposable virtual cards?
# 6443                                             I have a duplicate payment on my account
# 391                      I am travelling and I was wondering what your exchange rates are
# 6708                                                 what is the time frame for transfers
# 7741                                                Where is my top-up verification code?
# 9888                                                    Which countries do you operate in
#
#                             category
# 9473          cash_withdrawal_charge
# 8849  cash_withdrawal_not_recognised
# 2397   wrong_amount_of_cash_received
# 4274              topping_up_by_card
# 8399     get_disposable_virtual_card
# 6443       transaction_charged_twice
# 391                    exchange_rate
# 6708                 transfer_timing
# 7741                   verify_top_up
# 9888                 country_support

# %%
len(data_full)
# Out:
# 10003

# %%
(data_full.category.value_counts()
                   .to_frame()
                   .reset_index()
                   .rename(columns={'index': 'intent', 'category': 'count'}))
# Out:
#                                               intent  count
# 0                           card_payment_fee_charged    187
# 1                direct_debit_payment_not_recognised    182
# 2   balance_not_updated_after_cheque_or_cash_deposit    181
# 3                      wrong_amount_of_cash_received    180
# 4                             cash_withdrawal_charge    177
# 5                          transaction_charged_twice    175
# 6                           declined_cash_withdrawal    173
# 7                               transfer_fee_charged    172
# 8                 transfer_not_received_by_recipient    171
# 9            balance_not_updated_after_bank_transfer    171
# 10                                    request_refund    169
# 11                       card_payment_not_recognised    168
# 12                  card_payment_wrong_exchange_rate    167
# 13                         extra_charge_on_statement    166
# 14           wrong_exchange_rate_for_cash_withdrawal    163
# 15                             Refund_not_showing_up    162
# 16                            reverted_card_payment?    161
# 17                    cash_withdrawal_not_recognised    160
# 18                                  activate_my_card    159
# 19                              pending_card_payment    159
# 20                                   cancel_transfer    157
# 21                           beneficiary_not_allowed    156
# 22                             declined_card_payment    153
# 23                                      card_arrival    153
# 24                                    pending_top_up    149
# 25                                  pending_transfer    148
# 26                                   top_up_reverted    146
# 27                                     top_up_failed    145
# 28                           pending_cash_withdrawal    143
# 29                                      card_linking    139
# 30                                   failed_transfer    137
# 31                                visa_or_mastercard    135
# 32                                 declined_transfer    133
# 33                                   country_support    129
# 34                                getting_spare_card    129
# 35                    supported_cards_and_currencies    129
# 36                              card_about_to_expire    129
# 37                                   transfer_timing    128
# 38                                  automatic_top_up    127
# 39                           apple_pay_or_google_pay    126
# 40                                     verify_top_up    126
# 41                             fiat_currency_support    126
# 42                                        change_pin    122
# 43                              lost_or_stolen_phone    121
# 44                                   exchange_charge    121
# 45                            disposable_card_limits    121
# 46                             edit_personal_details    121
# 47                               why_verify_identity    121
# 48                               order_physical_card    120
# 49                                  exchange_via_app    118
# 50                                       pin_blocked    115
# 51                             top_up_by_card_charge    114
# 52                          top_up_by_cash_or_cheque    114
# 53                             transfer_into_account    113
# 54                            verify_source_of_funds    113
# 55                                     exchange_rate    112
# 56                            card_delivery_estimate    112
# 57                                  card_not_working    112
# 58                    top_up_by_bank_transfer_charge    111
# 59                                         age_limit    110
# 60                                 terminate_account    108
# 61                                 get_physical_card    106
# 62                                passcode_forgotten    105
# 63                                verify_my_identity    104
# 64                                topping_up_by_card    103
# 65                         unable_to_verify_identity    102
# 66                              getting_virtual_card     98
# 67                                     top_up_limits     97
# 68                       get_disposable_virtual_card     97
# 69                                   receiving_money     95
# 70                                       atm_support     87
# 71                                  compromised_card     86
# 72                               lost_or_stolen_card     82
# 73                                    card_swallowed     61
# 74                                   card_acceptance     59
# 75                          virtual_card_not_working     41
# 76                           contactless_not_working     35

# %%
data_full[data_full['category']=='card_swallowed']
# Out:
#                                                                                                                                                text  \
# 6245                                                                                                          What do I do if the ATM took my card?
# 6246                                                                                 What do I do now my credit card has been swallowed by the ATM?
# 6247                                                                                                    An ATM machine didn't give me back my card.
# 6248                                                                                           My card got trapped inside an ATM, what should I do?
# 6249                                                                                            What do I do if I can't get my card out of the ATM?
# 6250                                                                                                                   My card got stuck in an ATM.
# 6251                                                                                               Your machine took my card. How do I get it back?
# 6252                                                                                      I can't get my card out of the ATM, what should I do now?
# 6253                                                                                                                   My card is stuck in the ATM?
# 6254                                                                                                        I didn't get my card back from the ATM.
# 6255  The ATM at Metro bank on High St. Kensington didn't return my card, and the bank is now closed. How do I get back a card swallowed by an ATM?
# 6256                                                                                                   I need a new card because the ATM took mine.
# 6257                                                                                                                         The ATM stole my card!
# 6258                                                                                       How can I get my card out of the stupid ATM that ate it?
# 6259                                                                                                                          The ATM took my card.
# 6260                                                                                        The ATM won't give me my card back. I need it back now!
# 6261                                                                                 How do I get my card back quickly from a bank machine that it?
# 6262                                                                                                                     The ATM sucked my card in.
# 6263                                                                                                          The ATM did not give me my card back?
# 6264                                                                                               I was getting cash and the card got stuck inside
# 6265                                                                                          What should I do since my card is trapped in the ATM?
# 6266                                                                                                  what do I need to do if the ATM kept my card?
# 6267                                                                                                    The ATM machine would not give my card back
# 6268                                                                                                             I can't get my card out of the ATM
# 6269                                                                                                      Why did the ATM take my card and keep it?
# 6270                                                                               What are the steps to get my card back that was kept by the ATM?
# 6271                                                                                                           How do I get my card out of the ATM?
# 6272                                                                                                                   Why did the ATM eat my card?
# 6273                                                                                                      Please send a new card; the ATM ate mine.
# 6274                                                                                                                  The ATM didnt return my card!
# 6275                                                           I was removing a dollar amount from my account and now don't have access to my card.
# 6276                                                                                        A Bank ATM did not give my card back. What do I do now?
# 6277                                                                                                               Why did the ATM swallow my card?
# 6278                                                                                                                            lost my card in atm
# 6279                                                                                                           I cannot get my card out of the ATM.
# 6280                                                                                                          An ATM machine didn't return my card.
# 6281                                                                                                               My card is stuck inside the ATM.
# 6282                                                                         The bank machine didn't give my card back how do I get a new one fast?
# 6283                                                                                                      What should I do if the atm eats my card?
# 6284                                                                                                           What do I do?  The ATM took my card!
# 6285                                                                                                                          The ATM kept my card?
# 6286                                                                                             Who do I talk to about the ATM swallowing my card?
# 6287                                                                                                               An ATM swallowed my credit card!
# 6288                                                                                                     What do I do if the ATM swallowed my card?
# 6289                                                                                          Please help, the atm swallowed my card, what do I do?
# 6290                                                                                                         I have lost my credit card in the ATM!
# 6291                                                                                   how can the money machine keep my card what do i need to do?
# 6292                                                                                        How do I get a new card as your machine swallowed mine!
# 6293                                                                                                                   The ATM machine ate my card.
# 6294                                                                                                          how to get new card after atm eats it
# 6295                                                                                            My card was eaten by the cash machine what do I do?
# 6296                                                                                                      What do I do after the ATM takes my card.
# 6297                                                                                                          How can I get my card out of the ATM?
# 6298                                                                                                      Will you please help me get my card back?
# 6299                                                                                                   The ATM ate my card; how do I get a new one?
# 6300                                                                                          How do I get my card back after the ATM swallowed it.
# 6301                                                                              My card is stuck in an ATM machine, how do I get it back quickly?
# 6302                                                                                                                                atm ate my card
# 6303                                                                                 What are the steps I should take to recover my swallowed card?
# 6304                                                                                     My card is stuck inside the ATM, what am I supposed to do?
# 6305                                                                                                            What should I do with my stuck ATM?
#
#             category
# 6245  card_swallowed
# 6246  card_swallowed
# 6247  card_swallowed
# 6248  card_swallowed
# 6249  card_swallowed
# 6250  card_swallowed
# 6251  card_swallowed
# 6252  card_swallowed
# 6253  card_swallowed
# 6254  card_swallowed
# 6255  card_swallowed
# 6256  card_swallowed
# 6257  card_swallowed
# 6258  card_swallowed
# 6259  card_swallowed
# 6260  card_swallowed
# 6261  card_swallowed
# 6262  card_swallowed
# 6263  card_swallowed
# 6264  card_swallowed
# 6265  card_swallowed
# 6266  card_swallowed
# 6267  card_swallowed
# 6268  card_swallowed
# 6269  card_swallowed
# 6270  card_swallowed
# 6271  card_swallowed
# 6272  card_swallowed
# 6273  card_swallowed
# 6274  card_swallowed
# 6275  card_swallowed
# 6276  card_swallowed
# 6277  card_swallowed
# 6278  card_swallowed
# 6279  card_swallowed
# 6280  card_swallowed
# 6281  card_swallowed
# 6282  card_swallowed
# 6283  card_swallowed
# 6284  card_swallowed
# 6285  card_swallowed
# 6286  card_swallowed
# 6287  card_swallowed
# 6288  card_swallowed
# 6289  card_swallowed
# 6290  card_swallowed
# 6291  card_swallowed
# 6292  card_swallowed
# 6293  card_swallowed
# 6294  card_swallowed
# 6295  card_swallowed
# 6296  card_swallowed
# 6297  card_swallowed
# 6298  card_swallowed
# 6299  card_swallowed
# 6300  card_swallowed
# 6301  card_swallowed
# 6302  card_swallowed
# 6303  card_swallowed
# 6304  card_swallowed
# 6305  card_swallowed

# %% [markdown]
# Take a sample of the larger dataset to use for much of the analysis.

# %%
data_sample = data_full.sample(n=1000, random_state=123)

# %%
data_sample.category.value_counts()
# Out:
# Refund_not_showing_up                               26
# cash_withdrawal_charge                              24
# cancel_transfer                                     23
# pending_card_payment                                23
# transfer_not_received_by_recipient                  22
# direct_debit_payment_not_recognised                 22
# cash_withdrawal_not_recognised                      21
# request_refund                                      21
# verify_top_up                                       18
# verify_source_of_funds                              18
# balance_not_updated_after_cheque_or_cash_deposit    18
# declined_card_payment                               17
# wrong_amount_of_cash_received                       17
# declined_cash_withdrawal                            17
# wrong_exchange_rate_for_cash_withdrawal             17
# card_payment_not_recognised                         17
# visa_or_mastercard                                  17
# transfer_fee_charged                                17
# top_up_by_bank_transfer_charge                      16
# transfer_timing                                     16
# activate_my_card                                    16
# transaction_charged_twice                           16
# pending_cash_withdrawal                             16
# automatic_top_up                                    16
# get_disposable_virtual_card                         15
# fiat_currency_support                               15
# order_physical_card                                 15
# declined_transfer                                   14
# card_about_to_expire                                14
# pending_top_up                                      14
# reverted_card_payment?                              14
# extra_charge_on_statement                           14
# country_support                                     13
# terminate_account                                   13
# change_pin                                          13
# lost_or_stolen_phone                                12
# beneficiary_not_allowed                             12
# top_up_by_card_charge                               12
# passcode_forgotten                                  12
# supported_cards_and_currencies                      12
# apple_pay_or_google_pay                             12
# top_up_failed                                       12
# get_physical_card                                   12
# card_not_working                                    12
# card_payment_wrong_exchange_rate                    12
# pending_transfer                                    11
# top_up_reverted                                     11
# card_payment_fee_charged                            11
# card_linking                                        10
# lost_or_stolen_card                                 10
# atm_support                                         10
# receiving_money                                     10
# balance_not_updated_after_bank_transfer             10
# age_limit                                           10
# getting_spare_card                                  10
# topping_up_by_card                                  10
# card_delivery_estimate                               9
# disposable_card_limits                               9
# why_verify_identity                                  9
# unable_to_verify_identity                            9
# getting_virtual_card                                 9
# card_arrival                                         9
# exchange_rate                                        9
# exchange_charge                                      8
# exchange_via_app                                     8
# failed_transfer                                      8
# edit_personal_details                                8
# top_up_by_cash_or_cheque                             8
# verify_my_identity                                   8
# top_up_limits                                        8
# transfer_into_account                                7
# card_acceptance                                      7
# virtual_card_not_working                             7
# compromised_card                                     6
# contactless_not_working                              6
# card_swallowed                                       5
# pin_blocked                                          5
# Name: category, dtype: int64

# %% [markdown]
# ### Clean data

# %%
stop_words = set(stopwords.words('english'))

print(stop_words)
# Out:
# {'same', 'itself', "you'd", "shouldn't", "it's", 'needn', 'will', "mustn't", 'wasn', 'nor', 'hadn', 'other', 'll', 'isn', 'and', "won't", 'down', 'myself', 'any', 'now', 'what', 'again', 'does', 'between', "didn't", 'where', 'shan', 'over', "needn't", 'yourselves', 'this', "couldn't", 'd', 'won', 'no', 'y', 'am', 'but', 'while', 't', 'those', 'hasn', 'once', 'about', 'had', 'because', 'has', 'wouldn', 'more', 'it', 'do', 'our', 'are', 'of', 'ourselves', 'be', "aren't", 'here', 'from', 'out', 'yourself', 'through', 've', "should've", "doesn't", "hadn't", 'you', 'didn', "hasn't", 'shouldn', 'before', 'how', 'so', "isn't", 'or', 'being', 'whom', "you'll", 'with', 'her', 'was', 'at', 'which', 'have', 'doing', 'ma', 'for', 'their', 'when', 'both', 'that', 'as', 'by', "wasn't", "wouldn't", 'can', 'hers', 'if', "don't", 'why', 'they', 'who', 'mightn', 'its', "weren't", 'too', 'don', 're', 's', "that'll", 'your', 'very', 'doesn', 'yours', 'above', 'ain', 'some', "she's", 'into', 'than', 'she', 'below', 'only', 'just', 'is', 'haven', 'my', 'theirs', "you're", 'after', 'couldn', 'were', 'himself', 'few', 'on', 'not', 'o', 'themselves', 'in', 'there', 'm', 'mustn', 'under', 'a', 'to', 'me', 'did', 'we', 'during', 'the', 'these', "you've", 'then', 'most', 'herself', 'all', 'him', 'ours', 'them', 'been', 'an', 'until', 'i', 'against', 'he', 'should', "haven't", 'further', 'weren', 'aren', 'off', "shan't", 'up', 'such', 'each', 'having', "mightn't", 'his', 'own'}

# %%
def clean_text(text):
    """
    Summary: turns text input string into list of cleaned word tokens
    
    Arguments:
        text: str of text
    
    Returns:
        lemmatized_words: str, lemmatized words from original text after cleaning
    """
    
    # remove numbers
    clean_text = re.sub(r'[0-9]+', '', text)
    
    # remove punctuation
    clean_text = re.sub(r'[^\w\s]', '', clean_text)
    
    # convert everything to lowercase
    clean_text = clean_text.lower()
    
    # tokenize
    wt = WhitespaceTokenizer()
    words = wt.tokenize(clean_text)
    
    # remove stop words
    cleaned_words = []
    for w in words:
        if w not in stop_words:
            cleaned_words.append(w)
            
    # lemmatize words
    wnl = WordNetLemmatizer()
    wnl_lemmatized_tokens = []
    for token in cleaned_words:
        wnl_lemmatized_tokens.append(wnl.lemmatize(token))
    
    lemmatized_words = ' '.join(wnl_lemmatized_tokens)
    
    return lemmatized_words

# %%
data_sample['cleaned_text'] = data_sample['text'].apply(lambda x: clean_text(x))
data_sample.head()
# Out:
#                                                                                                                 text  \
# 1024                         I'm worried my card might be lost in the mail? How long does it usually take to arrive?
# 9405                                                        I got charged a fee that shouldn't be there from my cash
# 9368  Do you charge for making a withdrawal? I took some money out of my account earlier and I was charged for this.
# 3414         Is there an issue with my account?  I don't see a cheque deposit that I made yesterday.  Please assist.
# 7402                                                               Are there ways for other people to send me money?
#
#                                               category  \
# 1024                            card_delivery_estimate
# 9405                            cash_withdrawal_charge
# 9368                            cash_withdrawal_charge
# 3414  balance_not_updated_after_cheque_or_cash_deposit
# 7402                                   receiving_money
#
#                                                             cleaned_text
# 1024            im worried card might lost mail long usually take arrive
# 9405                                       got charged fee shouldnt cash
# 9368         charge making withdrawal took money account earlier charged
# 3414  issue account dont see cheque deposit made yesterday please assist
# 7402                                               way people send money

# %%
sample_text = ' '.join(list(data_sample['text'].values))
print(sample_text[0:400])
# Out:
# I'm worried my card might be lost in the mail? How long does it usually take to arrive? I got charged a fee that shouldn't be there from my cash Do you charge for making a withdrawal? I took some money out of my account earlier and I was charged for this. Is there an issue with my account?  I don't see a cheque deposit that I made yesterday.  Please assist. Are there ways for other people to send

# %%
clean_sample_text = ' '.join(list(data_sample['cleaned_text'].values))
print(clean_sample_text[0:400])
# Out:
# im worried card might lost mail long usually take arrive got charged fee shouldnt cash charge making withdrawal took money account earlier charged issue account dont see cheque deposit made yesterday please assist way people send money receive money change address still received new card anywhere cant use card want multiple currency account possible wouldnt atm give cash business eu add people acc

# %% [markdown]
# ### Word distributions across all messages in sample

# %%
# tokenize
wt = WhitespaceTokenizer()
clean_tokens = wt.tokenize(clean_sample_text)

freq_dist = FreqDist(clean_tokens)
print(freq_dist)
# Out:
# <FreqDist with 810 samples and 5351 outcomes>

# %%
freq_dist.most_common(500)
# Out:
# [('card', 282),
#  ('account', 130),
#  ('money', 110),
#  ('transfer', 109),
#  ('payment', 96),
#  ('need', 75),
#  ('cash', 73),
#  ('get', 73),
#  ('please', 67),
#  ('top', 62),
#  ('charged', 54),
#  ('app', 51),
#  ('fee', 50),
#  ('atm', 50),
#  ('help', 48),
#  ('use', 47),
#  ('refund', 45),
#  ('pending', 44),
#  ('long', 43),
#  ('made', 43),
#  ('exchange', 43),
#  ('transaction', 42),
#  ('topup', 42),
#  ('currency', 39),
#  ('would', 39),
#  ('withdrawal', 38),
#  ('take', 37),
#  ('rate', 37),
#  ('charge', 34),
#  ('didnt', 34),
#  ('still', 33),
#  ('new', 33),
#  ('time', 33),
#  ('dont', 32),
#  ('wrong', 32),
#  ('like', 32),
#  ('know', 31),
#  ('make', 31),
#  ('pin', 31),
#  ('declined', 30),
#  ('im', 28),
#  ('working', 28),
#  ('got', 27),
#  ('see', 27),
#  ('virtual', 27),
#  ('tried', 27),
#  ('want', 26),
#  ('yet', 26),
#  ('show', 25),
#  ('using', 25),
#  ('work', 24),
#  ('bank', 24),
#  ('cant', 23),
#  ('cancel', 23),
#  ('getting', 23),
#  ('go', 23),
#  ('tell', 22),
#  ('check', 22),
#  ('disposable', 22),
#  ('one', 22),
#  ('statement', 20),
#  ('fund', 20),
#  ('identity', 20),
#  ('amount', 20),
#  ('going', 19),
#  ('pay', 19),
#  ('showing', 19),
#  ('someone', 19),
#  ('whats', 18),
#  ('find', 18),
#  ('withdraw', 18),
#  ('isnt', 18),
#  ('purchase', 18),
#  ('something', 18),
#  ('hasnt', 18),
#  ('ago', 18),
#  ('change', 17),
#  ('extra', 17),
#  ('used', 17),
#  ('receive', 16),
#  ('received', 16),
#  ('possible', 16),
#  ('ive', 15),
#  ('debit', 15),
#  ('mastercard', 14),
#  ('verify', 14),
#  ('direct', 14),
#  ('balance', 14),
#  ('sent', 14),
#  ('much', 13),
#  ('cost', 13),
#  ('accept', 13),
#  ('keep', 13),
#  ('verification', 13),
#  ('today', 13),
#  ('cheque', 12),
#  ('give', 12),
#  ('order', 12),
#  ('visa', 12),
#  ('gone', 12),
#  ('right', 12),
#  ('country', 12),
#  ('back', 12),
#  ('stolen', 12),
#  ('reason', 12),
#  ('think', 12),
#  ('day', 12),
#  ('deposit', 11),
#  ('missing', 11),
#  ('wont', 11),
#  ('doesnt', 11),
#  ('phone', 11),
#  ('could', 11),
#  ('item', 11),
#  ('passcode', 11),
#  ('able', 11),
#  ('wasnt', 11),
#  ('correct', 11),
#  ('come', 11),
#  ('cancelled', 11),
#  ('couple', 11),
#  ('friend', 11),
#  ('earlier', 10),
#  ('yesterday', 10),
#  ('service', 10),
#  ('many', 10),
#  ('bought', 10),
#  ('physical', 10),
#  ('already', 10),
#  ('number', 10),
#  ('really', 10),
#  ('add', 9),
#  ('transferred', 9),
#  ('available', 9),
#  ('explain', 9),
#  ('activate', 9),
#  ('soon', 9),
#  ('access', 9),
#  ('waiting', 9),
#  ('seems', 9),
#  ('since', 9),
#  ('hour', 9),
#  ('week', 9),
#  ('lost', 8),
#  ('china', 8),
#  ('additional', 8),
#  ('happened', 8),
#  ('hi', 8),
#  ('set', 8),
#  ('might', 7),
#  ('source', 7),
#  ('trying', 7),
#  ('havent', 7),
#  ('say', 7),
#  ('merchant', 7),
#  ('remember', 7),
#  ('twice', 7),
#  ('look', 7),
#  ('google', 7),
#  ('went', 7),
#  ('foreign', 7),
#  ('different', 7),
#  ('delete', 7),
#  ('deposited', 7),
#  ('sure', 7),
#  ('requested', 7),
#  ('way', 6),
#  ('limit', 6),
#  ('auto', 6),
#  ('seem', 6),
#  ('problem', 6),
#  ('code', 6),
#  ('credit', 6),
#  ('abroad', 6),
#  ('without', 6),
#  ('paid', 6),
#  ('done', 6),
#  ('instead', 6),
#  ('system', 6),
#  ('left', 6),
#  ('process', 6),
#  ('another', 6),
#  ('store', 6),
#  ('arrived', 6),
#  ('taking', 6),
#  ('request', 6),
#  ('gbp', 6),
#  ('may', 6),
#  ('recognize', 6),
#  ('morning', 6),
#  ('expect', 6),
#  ('beneficiary', 6),
#  ('incorrect', 6),
#  ('checked', 6),
#  ('everything', 6),
#  ('multiple', 5),
#  ('let', 5),
#  ('place', 5),
#  ('recently', 5),
#  ('topups', 5),
#  ('verified', 5),
#  ('noticed', 5),
#  ('second', 5),
#  ('daughter', 5),
#  ('failed', 5),
#  ('apple', 5),
#  ('wallet', 5),
#  ('updated', 5),
#  ('option', 5),
#  ('hotel', 5),
#  ('withdrew', 5),
#  ('contactless', 5),
#  ('u', 5),
#  ('error', 5),
#  ('strange', 5),
#  ('there', 5),
#  ('automatically', 5),
#  ('changed', 5),
#  ('asked', 5),
#  ('topping', 5),
#  ('swift', 5),
#  ('understand', 5),
#  ('trouble', 5),
#  ('believe', 5),
#  ('european', 5),
#  ('step', 5),
#  ('thought', 5),
#  ('buy', 5),
#  ('uk', 5),
#  ('figure', 5),
#  ('complete', 5),
#  ('completed', 5),
#  ('info', 5),
#  ('eur', 5),
#  ('message', 5),
#  ('shouldnt', 4),
#  ('making', 4),
#  ('took', 4),
#  ('issue', 4),
#  ('send', 4),
#  ('address', 4),
#  ('wait', 4),
#  ('seller', 4),
#  ('rent', 4),
#  ('name', 4),
#  ('returned', 4),
#  ('thing', 4),
#  ('revert', 4),
#  ('though', 4),
#  ('via', 4),
#  ('online', 4),
#  ('sepa', 4),
#  ('delivery', 4),
#  ('duplicate', 4),
#  ('away', 4),
#  ('purchased', 4),
#  ('location', 4),
#  ('old', 4),
#  ('applied', 4),
#  ('saw', 4),
#  ('hello', 4),
#  ('came', 4),
#  ('company', 4),
#  ('put', 4),
#  ('receiving', 4),
#  ('offer', 4),
#  ('prove', 4),
#  ('ordered', 4),
#  ('unable', 4),
#  ('two', 4),
#  ('else', 4),
#  ('pound', 4),
#  ('withdrawing', 4),
#  ('id', 4),
#  ('expires', 4),
#  ('information', 4),
#  ('happens', 4),
#  ('ok', 4),
#  ('several', 4),
#  ('stop', 4),
#  ('return', 4),
#  ('worried', 3),
#  ('arrive', 3),
#  ('people', 3),
#  ('eu', 3),
#  ('never', 3),
#  ('free', 3),
#  ('age', 3),
#  ('fix', 3),
#  ('fiat', 3),
#  ('tomorrow', 3),
#  ('mine', 3),
#  ('transferring', 3),
#  ('suddenly', 3),
#  ('stopped', 3),
#  ('even', 3),
#  ('express', 3),
#  ('close', 3),
#  ('mistake', 3),
#  ('worked', 3),
#  ('europe', 3),
#  ('holiday', 3),
#  ('urgently', 3),
#  ('immediately', 3),
#  ('aud', 3),
#  ('reset', 3),
#  ('listed', 3),
#  ('attempted', 3),
#  ('procedure', 3),
#  ('bad', 3),
#  ('detail', 3),
#  ('finding', 3),
#  ('identification', 3),
#  ('link', 3),
#  ('salary', 3),
#  ('checking', 3),
#  ('coming', 3),
#  ('happening', 3),
#  ('machine', 3),
#  ('processed', 3),
#  ('activating', 3),
#  ('heard', 3),
#  ('stole', 3),
#  ('pretty', 3),
#  ('found', 3),
#  ('customer', 3),
#  ('support', 3),
#  ('appears', 3),
#  ('normally', 3),
#  ('frame', 3),
#  ('nothing', 3),
#  ('reverted', 3),
#  ('exchanged', 3),
#  ('okay', 3),
#  ('faster', 3),
#  ('automatic', 3),
#  ('appear', 3),
#  ('asap', 3),
#  ('hold', 3),
#  ('wheres', 3),
#  ('le', 3),
#  ('first', 3),
#  ('provide', 3),
#  ('added', 3),
#  ('create', 3),
#  ('freeze', 3),
#  ('mail', 2),
#  ('assist', 2),
#  ('wouldnt', 2),
#  ('business', 2),
#  ('unhappy', 2),
#  ('always', 2),
#  ('overseas', 2),
#  ('replacement', 2),
#  ('verifying', 2),
#  ('shown', 2),
#  ('disappeared', 2),
#  ('glitch', 2),
#  ('showed', 2),
#  ('ask', 2),
#  ('security', 2),
#  ('setting', 2),
#  ('home', 2),
#  ('vacation', 2),
#  ('bit', 2),
#  ('delivered', 2),
#  ('however', 2),
#  ('american', 2),
#  ('well', 2),
#  ('real', 2),
#  ('actual', 2),
#  ('interbank', 2),
#  ('gave', 2),
#  ('accidentally', 2),
#  ('documentation', 2),
#  ('rejected', 2),
#  ('stay', 2),
#  ('clearly', 2),
#  ('finish', 2),
#  ('per', 2),
#  ('person', 2),
#  ('try', 2),
#  ('hey', 2),
#  ('anymore', 2),
#  ('monthly', 2),
#  ('must', 2),
#  ('side', 2),
#  ('somebody', 2),
#  ('track', 2),
#  ('history', 2),
#  ('seeing', 2),
#  ('activated', 2),
#  ('charging', 2),
#  ('given', 2),
#  ('stuck', 2),
#  ('terminate', 2),
#  ('smart', 2),
#  ('according', 2),
#  ('half', 2),
#  ('product', 2),
#  ('paying', 2),
#  ('progress', 2),
#  ('reflect', 2),
#  ('random', 2),
#  ('actually', 2),
#  ('longer', 2),
#  ('far', 2),
#  ('update', 2),
#  ('operate', 2),
#  ('entered', 2),
#  ('enough', 2),
#  ('certain', 2),
#  ('denied', 2),
#  ('rule', 2),
#  ('suppose', 2),
#  ('restaurant', 2),
#  ('declining', 2),
#  ('fraud', 2),
#  ('open', 2),
#  ('forgotten', 2),
#  ('crypto', 2),
#  ('urgent', 2),
#  ('traveling', 2),
#  ('wanted', 2),
#  ('local', 2),
#  ('price', 2),
#  ('dissatisfied', 2),
#  ('international', 2),
#  ('accepted', 2),
#  ('cannot', 2),
#  ('refunded', 2),
#  ('posted', 2),
#  ('holding', 2),
#  ('often', 2),
#  ('car', 2),
#  ('ups', 2),
#  ('almost', 2),
#  ('expired', 2),
#  ('fast', 2),
#  ('supposed', 2),
#  ('recipient', 2),
#  ('best', 2),
#  ('failing', 2),
#  ('expire', 2),
#  ('refilled', 2),
#  ('overcharged', 2),
#  ('restriction', 2),
#  ('anyway', 2),
#  ('recent', 2),
#  ('house', 2),
#  ('fluffy', 2),
#  ('last', 2),
#  ('saying', 2),
#  ('also', 2),
#  ('large', 2),
#  ('cover', 2),
#  ('kid', 2),
#  ('double', 2),
#  ('guy', 2),
#  ('type', 2),
#  ('flat', 2),
#  ('entering', 2),
#  ('spend', 2),
#  ('attempt', 2),
#  ('fixed', 2),
#  ('permission', 2),
#  ('receipt', 2),
#  ('unsuccessful', 2),
#  ('anything', 2),
#  ('status', 2),
#  ('billing', 2),
#  ('odd', 2),
#  ('thats', 2),
#  ('dispute', 2),
#  ('required', 2),
#  ('require', 2),
#  ('past', 2),
#  ('acceptable', 2),
#  ('area', 2),
#  ('full', 2),
#  ('usually', 1),
#  ('anywhere', 1),
#  ('seen', 1),
#  ('pick', 1),
#  ('creditcard', 1),
#  ('brand', 1),
#  ('requirement', 1),
#  ('contacted', 1),
#  ('respond', 1),
#  ('directly', 1),
#  ('sudden', 1),
#  ('thru', 1),
#  ('office', 1),
#  ('thanks', 1),
#  ('wedding', 1),
#  ('spouse', 1),
#  ('fine', 1),
#  ('bay', 1),
#  ('reported', 1),
#  ('police', 1)]

# %%
freq_dist.get('account')
# Out:
# 130

# %%
fig, ax = plt.subplots(figsize=(12,8))
freq_dist.plot(20, cumulative=False)
plt.show()

# %% [markdown]
# ## Save cleaned data

# %%
data_sample.to_csv('../data/processed/data_sample.csv')
