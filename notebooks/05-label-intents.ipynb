# %% [markdown]
# # Chat Intents
#
# ## Applying labels

# %% [markdown]
# **Summary**
#
# This notebook provides a way to automatically extract and apply labels to document clusters. See the `chatintents_tutorial.ipynb` notebook for a tutorial of the chatintents package, which simplifies and makes it easier to use the methods outlined below.

# %%
import collections
from pathlib import Path

import numpy as np
import pandas as pd
import spacy
from spacy import displacy

pd.set_option("display.max_rows", 600)
pd.set_option("display.max_columns", 500)
pd.set_option("max_colwidth", 400)

# %%
nlp = spacy.load("en_core_web_sm")

# %%
data_clustered = pd.read_csv('../data/processed/sample_clustered.csv')
data_clustered = data_clustered[['text', 'label_st1']]
data_clustered.sample(10)
# Out:
#                                                                                                                text  \
# 840         Please help!  I was mugged and everything stolen.  What do I do to stop them from accessing my account?
# 141                                                            Can you explain why my Google Pay Top isn't working?
# 611  I recently made a transfer but I need to cancel it as soon as possible.  Please let me know when this happens.
# 906                               According to the app, I got cash from an ATM but I haven't made any transactions.
# 867                                                                            Do you give out Visa or Mastercards?
# 313                                                               I found my card! Can I link it back into the app?
# 101                                                            Can you tell me what I need for identity validation?
# 197                                                          I am trying to revert a transcation I did this morning
# 42                                                                  How do I check security settings using the app?
# 546                                                                               Please could you give me a refund
#
#      label_st1
# 840         14
# 141         13
# 611          9
# 906         -1
# 867         25
# 313         17
# 101         11
# 197          9
# 42           7
# 546          3

# %%
example_category = data_clustered[data_clustered['label_st1']==31].reset_index(drop=True)
example_category
# Out:
#                                                                                 text  \
# 0                              I am overseas in China, can I get a replacement card?
# 1                                                 Where are your cards delivered to?
# 2                                                              Do I get a real card?
# 3                                             I would like to purchase another card.
# 4                                                   tell me how I can order my card.
# 5                      What is the procedure for me to get more cards on my account?
# 6                                                     How to receive the actual card
# 7                                                         Where do we mail the card?
# 8                                                        Can I get a card in the EU?
# 9                                   Please tell me how I can receive a physical card
# 10                    If I am in China, can I still order a new card and if so, how?
# 11                                         What is the price for an additional card?
# 12                                                   Where do I go to order my card?
# 13                                        What fees are charged for a physical card?
# 14   My card is almost expired.  How fast will I get a new one and what is the cost?
# 15      My card is about to expire. Do I have to go to a branch to order a new card?
# 16                                                     Do physical cards cost money?
# 17                         My card expires soon, will you send me one automatically?
# 18  My card expires very soon.  What is the cost and delivery time to get a new one?
# 19       I would like to get a physical card, but I don't know how. Can you help me?
# 20                                   Where can I have a new bank card sent to China?
# 21                                                        Can I order a card please?
# 22                                               How do I get a new expiration date?
# 23                          Are there any express fees if i want my new card faster?
# 24                                                My card is almost going to expire.
# 25                                    I'm not in the UK, but can I still get a card?
# 26                                                              My card expires soon
# 27                            What is the cost and time frame of getting a new card?
# 28                         Can I get a physical card for free, or is there a charge?
# 29                              Are you only able to get a card if you're in the UK?
# 30                         Help me order a new card that's going to be expired soon.
# 31                                             what steps do i do to get a real card
# 32                                                                 I want a new card
# 33                                                  What happens if my card expires?
# 34                                                   I would like to request a card.
# 35                                          What's the procedure for getting a card?
# 36                                                  Can I have a supplementary card?
#
#     label_st1
# 0          31
# 1          31
# 2          31
# 3          31
# 4          31
# 5          31
# 6          31
# 7          31
# 8          31
# 9          31
# 10         31
# 11         31
# 12         31
# 13         31
# 14         31
# 15         31
# 16         31
# 17         31
# 18         31
# 19         31
# 20         31
# 21         31
# 22         31
# 23         31
# 24         31
# 25         31
# 26         31
# 27         31
# 28         31
# 29         31
# 30         31
# 31         31
# 32         31
# 33         31
# 34         31
# 35         31
# 36         31

# %%
example_doc = nlp(list(example_category['text'])[12])

print(f'{example_doc}\n')

for token in example_doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_ , token.is_stop)
# Out:
# Where do I go to order my card?
#
# Where where ADV WRB advmod True
# do do AUX VBP aux True
# I I PRON PRP nsubj True
# go go VERB VB ROOT True
# to to PART TO aux True
# order order VERB VB advcl False
# my my PRON PRP$ poss True
# card card NOUN NN dobj False
# ? ? PUNCT . punct False

# %%
displacy.render(example_doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="38ca952e74414f0cb14c548b17999e9c-0" class="displacy" width="1450" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Where</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">go</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">order</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">card?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-38ca952e74414f0cb14c548b17999e9c-0-0" stroke-width="2px" d="M70,264.5 C70,2.0 575.0,2.0 575.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-38ca952e74414f0cb14c548b17999e9c-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-38ca952e74414f0cb14c548b17999e9c-0-1" stroke-width="2px" d="M245,264.5 C245,89.5 570.0,89.5 570.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-38ca952e74414f0cb14c548b17999e9c-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-38ca952e74414f0cb14c548b17999e9c-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-38ca952e74414f0cb14c548b17999e9c-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-38ca952e74414f0cb14c548b17999e9c-0-3" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-38ca952e74414f0cb14c548b17999e9c-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,266.5 L762,254.5 778,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-38ca952e74414f0cb14c548b17999e9c-0-4" stroke-width="2px" d="M595,264.5 C595,89.5 920.0,89.5 920.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-38ca952e74414f0cb14c548b17999e9c-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,266.5 L928.0,254.5 912.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-38ca952e74414f0cb14c548b17999e9c-0-5" stroke-width="2px" d="M1120,264.5 C1120,177.0 1265.0,177.0 1265.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-38ca952e74414f0cb14c548b17999e9c-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-38ca952e74414f0cb14c548b17999e9c-0-6" stroke-width="2px" d="M945,264.5 C945,89.5 1270.0,89.5 1270.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-38ca952e74414f0cb14c548b17999e9c-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1270.0,266.5 L1278.0,254.5 1262.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>

# %%
fig = displacy.render(example_doc, style="dep", jupyter=False)
output_path = Path("../images/dependency_plot.svg") # you can keep there only "dependency_plot.svg" if you want to save it in the same folder where you run the script 
output_path.open("w", encoding="utf-8").write(fig)
# Out:
# 6335

# %% [markdown]
# ## Helper functions

# %%
def get_group(df, category_col, category):
    """
    Returns documents of a single category
    
    Arguments:
        df: pandas dataframe of documents
        category_col: str, column name corresponding to categories or clusters
        category: int, cluster number to return
    Returns:
        single_category: pandas dataframe with documents from a single category
    """
    
    single_category = df[df[category_col]==category].reset_index(drop=True)

    return single_category

# %%
def most_common(lst, n_words):
    """
    Get most common words in a list of words
    
    Arguments:
        lst: list, each element is a word
        n_words: number of top common words to return
    
    Returns:
        counter.most_common(n_words): counter object of n most common words
    """
    counter=collections.Counter(lst)
    return counter.most_common(n_words)

# %%
def extract_labels(category_docs, print_word_counts=False):
    """
    Extract labels from documents in the same cluster by concatenating
    most common verbs, ojects, and nouns

    Argument:
        category_docs: list of documents, all from the same category or
                       clustering
        print_word_counts: bool, True will print word counts of each type in this category

    Returns:
        label: str, group label derived from concatentating most common
               verb, object, and two most common nouns

    """

    verbs = []
    dobjs = []
    nouns = []
    adjs = []
    
    verb = ''
    dobj = ''
    noun1 = ''
    noun2 = ''

    # for each document, append verbs, dobs, nouns, and adjectives to 
    # running lists for whole cluster
    for i in range(len(category_docs)):
        doc = nlp(category_docs[i])
        for token in doc:
            if token.is_stop==False:
                if token.dep_ == 'ROOT':
                    verbs.append(token.text.lower())

                elif token.dep_=='dobj':
                    dobjs.append(token.lemma_.lower())

                elif token.pos_=='NOUN':
                    nouns.append(token.lemma_.lower())
                    
                elif token.pos_=='ADJ':
                    adjs.append(token.lemma_.lower())

    # for printing out for inspection purposes
    if print_word_counts:
        for word_lst in [verbs, dobjs, nouns, adjs]:
            counter=collections.Counter(word_lst)
            print(counter)
    
    # take most common words of each form
    if len(verbs) > 0:
        verb = most_common(verbs, 1)[0][0]
    
    if len(dobjs) > 0:
        dobj = most_common(dobjs, 1)[0][0]
    
    if len(nouns) > 0:
        noun1 = most_common(nouns, 1)[0][0]
    
    if len(set(nouns)) > 1:
        noun2 = most_common(nouns, 2)[1][0]
    
    # concatenate the most common verb-dobj-noun1-noun2 (if they exist)
    label_words = [verb, dobj]
    
    for word in [noun1, noun2]:
        if word not in label_words:
            label_words.append(word)
    
    if '' in label_words:
        label_words.remove('')
    
    label = '_'.join(label_words)
    
    return label

# %%
def apply_and_summarize_labels(df, category_col):
    """
    Assign groups to original documents and provide group counts

    Arguments:
        df: pandas dataframe of original documents of interest to
            cluster
        category_col: str, column name corresponding to categories or clusters

    Returns:
        summary_df: pandas dataframe with model cluster assignment, number
                    of documents in each cluster and derived labels
    """
    
    numerical_labels = df[category_col].unique()
    
    # create dictionary of the numerical category to the generated label
    label_dict = {}
    for label in numerical_labels:
        current_category = list(get_group(df, category_col, label)['text'])
        label_dict[label] = extract_labels(current_category)
        
    # create summary dataframe of numerical labels and counts
    summary_df = (df.groupby(category_col)['text'].count()
                    .reset_index()
                    .rename(columns={'text':'count'})
                    .sort_values('count', ascending=False))
    
    # apply generated labels
    summary_df['label'] = summary_df.apply(lambda x: label_dict[x[category_col]], axis = 1)
    
    return summary_df

# %%
def combine_ground_truth(df_clusters, df_ground, key):
    """
    Combines dataframes of documents with extracted and ground truth labels
    
    Arguments:
        df_clusters: pandas dataframe, each row as a document with corresponding extracted label
        df_ground: pandas dataframe, each row as a document with corresponding ground truth label
        key: str, key to merge tables on
        
    Returns:
        df_combined: pandas dataframe, each row as a document with extracted and ground truth labels
    """
    df_combined = pd.merge(df_clusters, df_ground, on=key, how = 'left')
    return df_combined

# %%
def get_top_category(df_label, df_summary):
    """
    Returns a dataframe comparing a single model's results to ground truth
    label to evalute cluster compositions and derived label relative to labels
    and counts of most commmon ground truth category

    Arguments:
        df_label: pandas dataframe, each row as a document with extracted and ground truth labels
                  (result of `combine_ground_truth` function)
        df_summary: pandas dataframe with model cluster assignment, number
                    of documents in each cluster and derived labels
                    (result from `apply_and_summarize_labels` function)

    Returns:
        df_result: pandas dataframe with each row containing information on
                   each cluster identified by this model, including count,
                   extracted label, most represented ground truth label name,
                   count and percentage of that group
    """
    df_label_ground = (df_label.groupby('label')
                      .agg(top_ground_category=('category', lambda x:x.value_counts().index[0]), 
                           top_cat_count = ('category', lambda x:x.value_counts()[0]))
                      .reset_index())
    
    df_result = pd.merge(df_summary, df_label_ground, on='label', how='left')
    df_result['perc_top_cat'] = df_result.apply(lambda x: int(round(100*x['top_cat_count']/x['count'])), axis=1)
    
    return df_result

# %% [markdown]
# ### Manual inspection

# %%
example_category = list(get_group(data_clustered, 'label_st1', 46)['text'])
extract_labels(example_category, True)
# Out:
# Counter({'help': 6, 'says': 1, 'withdrew': 1, 'checking': 1, 'understand': 1, 'believe': 1})
# Counter({'card': 4, 'withdrawal': 3, 'money': 1, 'account': 1, 'cash': 1, 'reason': 1})
# Counter({'account': 8, 'withdrawal': 5, 'cash': 3, 'withdraw': 1, 'card': 1, 'app': 1, 'money': 1, 'withdrawl': 1})
# Counter({'duplicate': 1, 'strange': 1, 'unexpected': 1, 'unusual': 1, 'odd': 1})
# 'help_card_account_withdrawal'

# %% [markdown]
# ### Without ground truth labels

# %%
cluster_summary = apply_and_summarize_labels(data_clustered, 'label_st1')
cluster_summary.head(20)
# Out:
#     label_st1  count                             label
# 0          -1     56                      add_card_app
# 27         26     49             use_account_card_auto
# 14         13     45             pending_money_account
# 4           3     44             help_refund_statement
# 15         14     38                     help_card_app
# 32         31     37                    like_card_cost
# 5           4     36               think_rate_exchange
# 34         33     31            tried_money_card_today
# 33         32     31       charged_fee_withdrawal_cash
# 30         29     29                  use_currency_app
# 19         18     28                explain_card_limit
# 13         12     28              waiting_payment_card
# 36         35     25                  charged_card_fee
# 10          9     25  cancel_transfer_account_tomorrow
# 50         49     24          waiting_transfer_account
# 22         21     22                     want_pin_card
# 16         15     22         charged_fee_transfer_bank
# 46         45     19            tried_transfer_account
# 39         38     19            cancelled_payment_card
# 20         19     18            find_source_fund_money

# %%
labeled_clusters = pd.merge(data_clustered, cluster_summary[['label_st1', 'label']], on='label_st1', how = 'left')
labeled_clusters.head()
# Out:
#                                                                                                              text  \
# 0                         I'm worried my card might be lost in the mail? How long does it usually take to arrive?
# 1                                                        I got charged a fee that shouldn't be there from my cash
# 2  Do you charge for making a withdrawal? I took some money out of my account earlier and I was charged for this.
# 3         Is there an issue with my account?  I don't see a cheque deposit that I made yesterday.  Please assist.
# 4                                                               Are there ways for other people to send me money?
#
#    label_st1                               label
# 0         30                    expect_card_week
# 1         32         charged_fee_withdrawal_cash
# 2         32         charged_fee_withdrawal_cash
# 3         53  deposited_cheque_balance_yesterday
# 4         51              sent_money_friend_hour

# %% [markdown]
# If we don't have the ground truth labels (which is the primary use case for this), then the above tables would be the final results. In this case, since we do have the ground truth labels we can investigate how well our model did.

# %% [markdown]
# ### With ground truth labels

# %%
data_ground = pd.read_csv('../data/processed/data_sample.csv')[['text', 'category']]
data_ground.head()
# Out:
#                                                                                                              text  \
# 0                         I'm worried my card might be lost in the mail? How long does it usually take to arrive?
# 1                                                        I got charged a fee that shouldn't be there from my cash
# 2  Do you charge for making a withdrawal? I took some money out of my account earlier and I was charged for this.
# 3         Is there an issue with my account?  I don't see a cheque deposit that I made yesterday.  Please assist.
# 4                                                               Are there ways for other people to send me money?
#
#                                            category
# 0                            card_delivery_estimate
# 1                            cash_withdrawal_charge
# 2                            cash_withdrawal_charge
# 3  balance_not_updated_after_cheque_or_cash_deposit
# 4                                   receiving_money

# %%
labeled_clusters = combine_ground_truth(labeled_clusters, data_ground, 'text')
labeled_clusters.sample(10)
# Out:
#                                                                                                                                            text  \
# 572                                                                                                    I've forgotten my passcode. Can I reset?
# 495                                                                                                     How can I investigate a missing refund?
# 989                                                                                                          How can I cancel this transaction?
# 565                                                                                                                  What currencies can I use?
# 548                                                                                                      How are the exchange rates determined?
# 416  Why hasn't my in country transfer gone through yet? I confirmed the account info a couple days ago but the payment hasn't been posted yet.
# 259                                                                                                                Why is this payment pending?
# 712                                                                           I was charged and shouldn't have been charged when using my card!
# 765                                                                                                                        My card expires soon
# 950                                                                                           How can I tell the source for my available funds?
#
#      label_st1                             label  \
# 572          2             remember_passcode_app
# 495          3             help_refund_statement
# 989          9  cancel_transfer_account_tomorrow
# 565         29                  use_currency_app
# 548          4               think_rate_exchange
# 416         49          waiting_transfer_account
# 259         12              waiting_payment_card
# 712         35                  charged_card_fee
# 765         31                    like_card_cost
# 950         19            find_source_fund_money
#
#                                category
# 572                  passcode_forgotten
# 495               Refund_not_showing_up
# 989                     cancel_transfer
# 565      supported_cards_and_currencies
# 548                       exchange_rate
# 416  transfer_not_received_by_recipient
# 259                pending_card_payment
# 712            card_payment_fee_charged
# 765                card_about_to_expire
# 950              verify_source_of_funds

# %% [markdown]
# The extracted labels (called 'label') match the ground label ('category') quite well for many of the sample documents.

# %%
labeled_clusters[labeled_clusters['label_st1']==45]
# Out:
#                                                                                                                                                                                               text  \
# 54                                                                                                                                                             Why does it say my transfer failed?
# 95                                                                                                                                                    I wasn't able to do a transfer to an account
# 247                                                                                                                                                 Can you please explain why my transfer failed?
# 283                                                                                                                                                   I went to do a transfer and it was declined.
# 316                                                                                                                                                           A transfer to my account was denied.
# 320                                                                                                                                             I tried to transfer money but it didn't go through
# 330                                                                                                                                  How do I contact customer support about my declined transfer?
# 377                                                                                                                                                          Why was one of my transfers declined?
# 379                                                                                                I normally have no issues making transfers, so why am I suddenly being told it is not possible?
# 472                                                                                                                                                    My transfer is failing when I try to do it.
# 526                                                                                                                                                                 Why can I not make a transfer?
# 542                                                                                                                                                      Why did I get declined during a transfer?
# 577                                                                                                                                                I tried to make a transfer, but it didn't work.
# 803                                                                                                                                                            I noticed my transfer was declined.
# 858                                                                                                                                        I refilled my account balance but got an error message.
# 861  I'm having problems making a transfer to another account. I keep getting a declined message. I know that the information I'm putting in is accurate because I have checked it more than once.
# 897                                                                                                                                                                   Why didn't my transfer work?
# 901                                                                                                                                                                 My transfer has been declined.
# 981                                                                                                                        I am trying to complete a transfer but I keep getting an error message.
#
#      label_st1                   label                 category
# 54          45  tried_transfer_account          failed_transfer
# 95          45  tried_transfer_account  beneficiary_not_allowed
# 247         45  tried_transfer_account          failed_transfer
# 283         45  tried_transfer_account        declined_transfer
# 316         45  tried_transfer_account  beneficiary_not_allowed
# 320         45  tried_transfer_account          failed_transfer
# 330         45  tried_transfer_account        declined_transfer
# 377         45  tried_transfer_account        declined_transfer
# 379         45  tried_transfer_account  beneficiary_not_allowed
# 472         45  tried_transfer_account          failed_transfer
# 526         45  tried_transfer_account          failed_transfer
# 542         45  tried_transfer_account        declined_transfer
# 577         45  tried_transfer_account          failed_transfer
# 803         45  tried_transfer_account        declined_transfer
# 858         45  tried_transfer_account          top_up_reverted
# 861         45  tried_transfer_account        declined_transfer
# 897         45  tried_transfer_account          failed_transfer
# 901         45  tried_transfer_account        declined_transfer
# 981         45  tried_transfer_account  beneficiary_not_allowed

# %% [markdown]
# #### Count and name of most common category of generated labels and clusters

# %%
get_top_category(labeled_clusters, cluster_summary)
# Out:
#     label_st1  count                                 label  \
# 0          -1     56                          add_card_app
# 1          26     49                 use_account_card_auto
# 2          13     45                 pending_money_account
# 3           3     44                 help_refund_statement
# 4          14     38                         help_card_app
# 5          31     37                        like_card_cost
# 6           4     36                   think_rate_exchange
# 7          33     31                tried_money_card_today
# 8          32     31           charged_fee_withdrawal_cash
# 9          29     29                      use_currency_app
# 10         18     28                    explain_card_limit
# 11         12     28                  waiting_payment_card
# 12         35     25                      charged_card_fee
# 13          9     25      cancel_transfer_account_tomorrow
# 14         49     24              waiting_transfer_account
# 15         21     22                         want_pin_card
# 16         15     22             charged_fee_transfer_bank
# 17         45     19                tried_transfer_account
# 18         38     19                cancelled_payment_card
# 19         19     18                find_source_fund_money
# 20         25     17  preferred_visa_mastercard_preference
# 21         10     17             use_identity_verification
# 22         44     15              remember_debit_statement
# 23         36     14            charged_charge_transaction
# 24         34     14                  receive_cash_account
# 25         30     14                      expect_card_week
# 26         22     13             need_account_daughter_age
# 27         28     13                 activate_card_process
# 28          6     13                  like_account_service
# 29         16     13                 charged_card_bank_fee
# 30         48     13               pending_withdrawal_cash
# 31         46     12          help_card_account_withdrawal
# 32          8     12                       use_card_person
# 33          2     12                 remember_passcode_app
# 34         51     12                sent_money_friend_hour
# 35         27     11                        work_card_time
# 36         50     11            transferred_money_transfer
# 37         52     11                deposited_cash_account
# 38          0     10                  need_up_verification
# 39         40     10              wanted_currency_exchange
# 40         42      9               need_money_account_bank
# 41         53      9    deposited_cheque_balance_yesterday
# 42         17      9                         link_card_app
# 43         41      8             need_help_payment_account
# 44         39      8             use_service_country_world
# 45         24      8              use_atm_circuit_location
# 46         47      8           need_transfer_delivery_time
# 47          7      8                        left_app_hotel
# 48          5      8                 change_address_spouse
# 49         43      7                 reimburse_payment_app
# 50         37      7                     tell_payment_card
# 51         23      7                      accept_card_work
# 52         20      7          need_pin_bank_representative
# 53         11      7     need_documentation_identity_check
# 54          1      7           find_card_verification_code
#
#                                  top_ground_category  top_cat_count  \
# 0                            beneficiary_not_allowed              8
# 1                                   automatic_top_up             14
# 2                                     pending_top_up             14
# 3                              Refund_not_showing_up             26
# 4                                lost_or_stolen_card             10
# 5                                order_physical_card             15
# 6            wrong_exchange_rate_for_cash_withdrawal             14
# 7                           declined_cash_withdrawal             14
# 8                             cash_withdrawal_charge             23
# 9                              fiat_currency_support             10
# 10                              getting_virtual_card              9
# 11                              pending_card_payment             21
# 12                          card_payment_fee_charged             11
# 13                                   cancel_transfer             22
# 14                                  pending_transfer             11
# 15                                 get_physical_card             12
# 16                              transfer_fee_charged             12
# 17                                   failed_transfer              7
# 18                            reverted_card_payment?             12
# 19                            verify_source_of_funds             17
# 20                                visa_or_mastercard             16
# 21                               why_verify_identity              9
# 22               direct_debit_payment_not_recognised             14
# 23                         transaction_charged_twice             14
# 24                     wrong_amount_of_cash_received             14
# 25                                      card_arrival              8
# 26                                         age_limit             10
# 27                                  activate_my_card             13
# 28                                 terminate_account             13
# 29                             top_up_by_card_charge             10
# 30                           pending_cash_withdrawal             13
# 31                    cash_withdrawal_not_recognised             11
# 32                       get_disposable_virtual_card              7
# 33                                passcode_forgotten             12
# 34                transfer_not_received_by_recipient              8
# 35                                  card_not_working              8
# 36                transfer_not_received_by_recipient              4
# 37  balance_not_updated_after_cheque_or_cash_deposit              9
# 38                                     verify_top_up             10
# 39                                   exchange_charge              7
# 40                             transfer_into_account              6
# 41  balance_not_updated_after_cheque_or_cash_deposit              9
# 42                                      card_linking              9
# 43                       card_payment_not_recognised              6
# 44                                   country_support              8
# 45                                       atm_support              8
# 46                                   transfer_timing              5
# 47                              lost_or_stolen_phone              5
# 48                             edit_personal_details              8
# 49                       card_payment_not_recognised              4
# 50                             declined_card_payment              6
# 51                                   card_acceptance              7
# 52                                        change_pin              7
# 53                                verify_my_identity              7
# 54                                     verify_top_up              7
#
#     perc_top_cat
# 0             14
# 1             29
# 2             31
# 3             59
# 4             26
# 5             41
# 6             39
# 7             45
# 8             74
# 9             34
# 10            32
# 11            75
# 12            44
# 13            88
# 14            46
# 15            55
# 16            55
# 17            37
# 18            63
# 19            94
# 20            94
# 21            53
# 22            93
# 23           100
# 24           100
# 25            57
# 26            77
# 27           100
# 28           100
# 29            77
# 30           100
# 31            92
# 32            58
# 33           100
# 34            67
# 35            73
# 36            36
# 37            82
# 38           100
# 39            70
# 40            67
# 41           100
# 42           100
# 43            75
# 44           100
# 45           100
# 46            62
# 47            62
# 48           100
# 49            57
# 50            86
# 51           100
# 52           100
# 53           100
# 54           100

# %% [markdown]
# Many of the smaller groups seem to be more pure (the top category is near or at 100%) compared to the larger groups. Thus, it makes sense that many of the extracted labels for the smaller groups tend to be more suitable than some of the extracted labels for the larger clusters, which have more varied representation of different ground truth clusters.
