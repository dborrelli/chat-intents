# %% [markdown]
# # Chat Intents
#
# ## Applying labels

# %%
import numpy as np
import pandas as pd

pd.set_option("display.max_rows", 600)
pd.set_option("display.max_columns", 500)
pd.set_option("max_colwidth", 400)

import collections

import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
data_clustered = pd.read_csv('../data/processed/sample_clustered.csv')
data_clustered = data_clustered[['text', 'label_st1']]
data_clustered.sample(10)
# Out:
#                                                          text  label_st1
# 222                           Do I need to verify the top-up?         17
# 525                             How do I activate my new card         47
# 159  I only got $20 of the $100 that I attempted to withdraw.         51
# 972                      Was there a problem with topping up?         19
# 136   What are ways to test why my card might not be working?         89
# 825                    I was overcharged an additional pound.         68
# 515                                  I need an ATM right now!         70
# 917                                My phone was stolen, help!         42
# 856                      Is there a certain age I need to be?          2
# 123                 Where can I get your exchange rates from?         54

# %%
#example_category = data_sample[data_sample['category']=='cash_withdrawal_charge'].reset_index(drop=True)
example_category = data_clustered[data_clustered['label_st1']==6].reset_index(drop=True)
example_category
# Out:
#                                                                                     text  \
# 0                          I want to have multiple currencies in my account if possible.
# 1                               I need to know which fiat currencies I can use with you.
# 2                                                Can i add a new currency to my account?
# 3                                                         what currencies do you accept?
# 4                                                        How many currencies can I have?
# 5   Can you tell me the names of the fiat currencies that I can use at your institution?
# 6                             What fiat currencies are used with holdings and exchanges?
# 7                                     Are there limitations to what currency I can hold?
# 8                                                             What currencies can I use?
# 9                         Which flat currencies do you support for holding and exchange?
# 10                                      Is it okay to hold money in multiple currencies?
# 11                               Can you tell me what currencies I can use to add money?
# 12                                             Which flat currencies can I use from you?
#
#     label_st1
# 0           6
# 1           6
# 2           6
# 3           6
# 4           6
# 5           6
# 6           6
# 7           6
# 8           6
# 9           6
# 10          6
# 11          6
# 12          6

# %%
example_doc = nlp(list(example_category['text'])[11])

for token in example_doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_ , token.is_stop)
# Out:
# Can can AUX MD aux True
# you you PRON PRP nsubj True
# tell tell VERB VB ROOT False
# me I PRON PRP dobj True
# what what PRON WP det True
# currencies currency NOUN NNS dobj False
# I I PRON PRP nsubj True
# can can AUX MD aux True
# use use VERB VB ccomp False
# to to PART TO aux True
# add add VERB VB xcomp False
# money money NOUN NN dobj False
# ? ? PUNCT . punct False

# %%
from spacy import displacy
from pathlib import Path

# %%
displacy.render(example_doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b2ca070aebdc4899a70f22a046bb6f4f-0" class="displacy" width="2150" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">tell</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">me</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">what</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">currencies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">use</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">add</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">money?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b2ca070aebdc4899a70f22a046bb6f4f-0-0" stroke-width="2px" d="M70,352.0 C70,177.0 390.0,177.0 390.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b2ca070aebdc4899a70f22a046bb6f4f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b2ca070aebdc4899a70f22a046bb6f4f-0-1" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b2ca070aebdc4899a70f22a046bb6f4f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b2ca070aebdc4899a70f22a046bb6f4f-0-2" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b2ca070aebdc4899a70f22a046bb6f4f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M560.0,354.0 L568.0,342.0 552.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b2ca070aebdc4899a70f22a046bb6f4f-0-3" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b2ca070aebdc4899a70f22a046bb6f4f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b2ca070aebdc4899a70f22a046bb6f4f-0-4" stroke-width="2px" d="M945,352.0 C945,89.5 1445.0,89.5 1445.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b2ca070aebdc4899a70f22a046bb6f4f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,354.0 L937,342.0 953,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b2ca070aebdc4899a70f22a046bb6f4f-0-5" stroke-width="2px" d="M1120,352.0 C1120,177.0 1440.0,177.0 1440.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b2ca070aebdc4899a70f22a046bb6f4f-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,354.0 L1112,342.0 1128,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b2ca070aebdc4899a70f22a046bb6f4f-0-6" stroke-width="2px" d="M1295,352.0 C1295,264.5 1435.0,264.5 1435.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b2ca070aebdc4899a70f22a046bb6f4f-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,354.0 L1287,342.0 1303,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b2ca070aebdc4899a70f22a046bb6f4f-0-7" stroke-width="2px" d="M420,352.0 C420,2.0 1450.0,2.0 1450.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b2ca070aebdc4899a70f22a046bb6f4f-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,354.0 L1458.0,342.0 1442.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc

# %%
fig = displacy.render(example_doc, style="dep", jupyter=False)
output_path = Path("../images/dependency_plot.svg") # you can keep there only "dependency_plot.svg" if you want to save it in the same folder where you run the script 
output_path.open("w", encoding="utf-8").write(fig)
# Out:
# 9689

# %% [markdown]
# ## Helper functions

# %%
def get_group(df, category_col, category):
    
    single_category = df[df[category_col]==category].reset_index(drop=True)

    return single_category

# %%
def most_common(lst, n_words):
    counter=collections.Counter(lst)
    return counter.most_common(n_words)

# %%
def extract_labels(category_docs, print_word_counts=False):
    """
    Argument:
    category_docs: list of documents, all from the same category or clustering
    """
    verbs = []
    dobjs = []
    nouns = []
    adjs = []
    
    verb = ''
    dobj = ''
    noun1 = ''
    noun2 = ''

    for i in range(len(category_docs)):
        doc = nlp(category_docs[i])
        for token in doc:
            if token.is_stop==False:
                if token.dep_ == 'ROOT':
                    verbs.append(token.text.lower())

                elif token.dep_=='dobj':
                    dobjs.append(token.lemma_.lower())

                elif token.pos_=='NOUN':
                    nouns.append(token.lemma_.lower())
                    
                elif token.pos_=='ADJ':
                    adjs.append(token.lemma_.lower())
                    #print(i, token.text, token.pos_, token.tag_, token.dep_ )

    if print_word_counts:
        for word_lst in [verbs, dobjs, nouns, adjs]:
            counter=collections.Counter(word_lst)
            print(counter)
        
    if len(verbs) > 0:
        verb = most_common(verbs, 1)[0][0]
    
    if len(dobjs) > 0:
        dobj = most_common(dobjs, 1)[0][0]
    
    if len(nouns) > 0:
        noun1 = most_common(nouns, 1)[0][0]
    
    if len(set(nouns)) > 1:
        noun2 = most_common(nouns, 2)[1][0]
    
    
    words = [verb, dobj]
    
    for word in [noun1, noun2]:
        if word not in words:
            words.append(word)
    
    if '' in words:
        words.remove('')
    
    label = '_'.join(words)
    
    return label

# %%
def apply_and_summarize_labels(df, category_col):
    numerical_labels = df[category_col].unique()
    
    # create dictionary of the numerical category to the generated label
    label_dict = {}
    for label in numerical_labels:
        current_category = list(get_group(df, category_col, label)['text'])
        label_dict[label] = extract_labels(current_category)
        
    # create summary dataframe of numerical labels and counts
    summary_df = (df.groupby(category_col)['text'].count()
                    .reset_index()
                    .rename(columns={'text':'count'})
                    .sort_values('count', ascending=False))
    
    # apply generated labels
    summary_df['label'] = summary_df.apply(lambda x: label_dict[x[category_col]], axis = 1)
    
    return summary_df

# %%
def combine_ground_truth(df_clusters, df_ground, key):
    df_combined = pd.merge(df_clusters, df_ground, on=key, how = 'left')
    return df_combined

# %%
def get_top_category(df_label, df_summary):
    df_label_ground = (df_label.groupby('label')
                      .agg(top_ground_category=('category', lambda x:x.value_counts().index[0]), 
                           top_cat_count = ('category', lambda x:x.value_counts()[0]))
                      .reset_index())
    
    df_result = pd.merge(df_summary, df_label_ground, on='label', how='left')
    df_result['perc_top_cat'] = df_result.apply(lambda x: int(round(100*x['top_cat_count']/x['count'])), axis=1)
    
    return df_result

# %% [markdown]
# ### Without ground truth labels

# %%
example_category = list(get_group(data_clustered, 'label_st1', 65)['text'])
extract_labels(example_category, True)
# Out:
# Counter({'tried': 4, 'pending': 3, 'taking': 2, 'ask': 1, 'finish': 1, 'need': 1, 'stays': 1, 'waiting': 1, 'receive': 1, 'fix': 1, 'think': 1, 'received': 1, 'saw': 1, 'arrived': 1, 'completed': 1, 'showing': 1, 'appear': 1, 'notice': 1, 'says': 1, 'saying': 1, 'happens': 1, 'noticing': 1, 'shopping': 1, 'going': 1, 'moved': 1})
# Counter({'payment': 9, 'money': 2, 'help': 1, 'frame': 1, 'purchase': 1, 'error': 1, 'message': 1})
# Counter({'payment': 16, 'card': 8, 'transaction': 5, 'time': 3, 'account': 3, 'friend': 3, 'couple': 2, 'day': 2, 'yesterday': 2, 'today': 2, 'progress': 1, 'merchant': 1, 'thing': 1, 'purchase': 1, 'morning': 1, 'money': 1, 'company': 1, 'store': 1, 'internet': 1, 'issue': 1})
# Counter({'long': 3, 'wrong': 2, 'strange': 1, 'embarrassing': 1})
# 'tried_payment_card'

# %%
cluster_summary = apply_and_summarize_labels(data_clustered, 'label_st1')
cluster_summary.head()
# Out:
#     label_st1  count                         label
# 0          -1     63             help_card_account
# 23         22     47           help_refund_account
# 66         65     32            tried_payment_card
# 67         66     29  deposited_money_account_cash
# 53         52     26   charged_fee_withdrawal_cash

# %%
labeled_clusters = pd.merge(data_clustered, cluster_summary[['label_st1', 'label']], on='label_st1', how = 'left')
labeled_clusters.head()
# Out:
#                                                                                                              text  \
# 0                         I'm worried my card might be lost in the mail? How long does it usually take to arrive?
# 1                                                        I got charged a fee that shouldn't be there from my cash
# 2  Do you charge for making a withdrawal? I took some money out of my account earlier and I was charged for this.
# 3         Is there an issue with my account?  I don't see a cheque deposit that I made yesterday.  Please assist.
# 4                                                               Are there ways for other people to send me money?
#
#    label_st1                         label
# 0         48              expect_card_week
# 1         52   charged_fee_withdrawal_cash
# 2         52   charged_fee_withdrawal_cash
# 3         66  deposited_money_account_cash
# 4         39      receive_money_charge_fee

# %% [markdown]
# ### With ground truth labels

# %%
data_ground = pd.read_csv('../data/processed/data_sample.csv')[['text', 'category']]
data_ground.head()
# Out:
#                                                                                                              text  \
# 0                         I'm worried my card might be lost in the mail? How long does it usually take to arrive?
# 1                                                        I got charged a fee that shouldn't be there from my cash
# 2  Do you charge for making a withdrawal? I took some money out of my account earlier and I was charged for this.
# 3         Is there an issue with my account?  I don't see a cheque deposit that I made yesterday.  Please assist.
# 4                                                               Are there ways for other people to send me money?
#
#                                            category
# 0                            card_delivery_estimate
# 1                            cash_withdrawal_charge
# 2                            cash_withdrawal_charge
# 3  balance_not_updated_after_cheque_or_cash_deposit
# 4                                   receiving_money

# %%
labeled_clusters = combine_ground_truth(labeled_clusters, data_ground, 'text')
labeled_clusters.head()
# Out:
#                                                                                                              text  \
# 0                         I'm worried my card might be lost in the mail? How long does it usually take to arrive?
# 1                                                        I got charged a fee that shouldn't be there from my cash
# 2  Do you charge for making a withdrawal? I took some money out of my account earlier and I was charged for this.
# 3         Is there an issue with my account?  I don't see a cheque deposit that I made yesterday.  Please assist.
# 4                                                               Are there ways for other people to send me money?
#
#    label_st1                         label  \
# 0         48              expect_card_week
# 1         52   charged_fee_withdrawal_cash
# 2         52   charged_fee_withdrawal_cash
# 3         66  deposited_money_account_cash
# 4         39      receive_money_charge_fee
#
#                                            category
# 0                            card_delivery_estimate
# 1                            cash_withdrawal_charge
# 2                            cash_withdrawal_charge
# 3  balance_not_updated_after_cheque_or_cash_deposit
# 4                                   receiving_money

# %%
labeled_clusters[labeled_clusters['label_st1']==65]
# Out:
#                                                                                                                                                              text  \
# 41                                                                            There is a payment that i made that i noticed has not gone thru yet. Can i ask why?
# 106                                                                                                                 What is the pending payment on my card about?
# 112                                                                                                                          When will my pending payment finish?
# 138                               My card payment has been pending for a long time now. Why is it taking so long to take. It should have already made it through.
# 152                                                                                                                I have a payment that hasn't went through yet.
# 163                                               I need some help figuring out what this strange payment is on my account. It's stays pending and won't go away.
# 166                                                                  Is there something wrong with my card payment? It's been pending a really, really long time.
# 240                      How long does it actually take for a card payment to go through? There's one stuck since a couple days already that doesn't seem to move
# 248                                                                                                                    I am waiting for a payment to be processed
# 259                                                                                                                                  Why is this payment pending?
# 291                                                                                                                      Why is the payment I made still pending?
# 296                                                           I didn't receive my money earlier and it says the transaction is still in progress. Can you fix it?
# 365                                                                    I made a payment with my card and it hasn't changed. How long do you think this will take?
# 401                                                                                                      Why hasn't my friend received the money i sent them yet?
# 405                                                                                       I saw a payment come out of my account for a merchant I don't remember.
# 462                                                                                                    Why hasn't the transaction I did to my friend arrived yet?
# 484  I completed a payment with my card a while ago. It's still showing up as pending. What time frame does this normally take? It doesn't appear to have worked.
# 491                               I tried to buy something online yesterday but it kept saying declined. Tried again today but same thing happened. What's wrong?
# 522                                                                 After I make a payment, how long will it be before it transitions from "pending" to complete?
# 523                                                                                                                I notice there's a pending payment on my card.
# 553                                                                                                             Why is my transaction taking so long to complete?
# 624                                                                                                                    There is a payment that has not processed.
# 629                                                                                                   My purchases from this morning still have pending payments.
# 639                                                                                                             It says "pending payment?" Why is it saying this?
# 796                                                                                                            Why is the transaction to my friend still pending?
# 834                                                                                  What happens when I money transaction doesn't show up on the receiving side?
# 838                                                                                          I'm noticing a payment/purchase at a company that I don't recognise.
# 864                            I was just shopping and my payment was declined in a store!  It was very embarrassing, what is going on and when will it be fixed?
# 908                 How long does it actually take my card payment to make it to the account? I've made a payment a couple of days ago but it hasn't moved since.
# 923                                                                                                                          There is a payment I don't recognize
# 994               I tried to buy something over the Internet yesterday and got a declined error. I tried again today and got the same message. What is the issue?
# 998                                                                                                                 I have a payment which has not been approved.
#
#      label_st1               label                            category
# 41          65  tried_payment_card                pending_card_payment
# 106         65  tried_payment_card                pending_card_payment
# 112         65  tried_payment_card                pending_card_payment
# 138         65  tried_payment_card                pending_card_payment
# 152         65  tried_payment_card                pending_card_payment
# 163         65  tried_payment_card           extra_charge_on_statement
# 166         65  tried_payment_card                pending_card_payment
# 240         65  tried_payment_card                pending_card_payment
# 248         65  tried_payment_card                pending_card_payment
# 259         65  tried_payment_card                pending_card_payment
# 291         65  tried_payment_card                pending_card_payment
# 296         65  tried_payment_card             pending_cash_withdrawal
# 365         65  tried_payment_card                pending_card_payment
# 401         65  tried_payment_card  transfer_not_received_by_recipient
# 405         65  tried_payment_card         card_payment_not_recognised
# 462         65  tried_payment_card  transfer_not_received_by_recipient
# 484         65  tried_payment_card                pending_card_payment
# 491         65  tried_payment_card                   declined_transfer
# 522         65  tried_payment_card                pending_card_payment
# 523         65  tried_payment_card                pending_card_payment
# 553         65  tried_payment_card  transfer_not_received_by_recipient
# 624         65  tried_payment_card                pending_card_payment
# 629         65  tried_payment_card                pending_card_payment
# 639         65  tried_payment_card                pending_card_payment
# 796         65  tried_payment_card  transfer_not_received_by_recipient
# 834         65  tried_payment_card  transfer_not_received_by_recipient
# 838         65  tried_payment_card         card_payment_not_recognised
# 864         65  tried_payment_card               declined_card_payment
# 908         65  tried_payment_card                pending_card_payment
# 923         65  tried_payment_card         card_payment_not_recognised
# 994         65  tried_payment_card                   declined_transfer
# 998         65  tried_payment_card                pending_card_payment

# %% [markdown]
# #### Count and name of most common category of generated labels and clusters

# %%
get_top_category(labeled_clusters, cluster_summary)
# Out:
#     label_st1  count                                   label  \
# 0          -1     63                       help_card_account
# 1          22     47                     help_refund_account
# 2          65     32                      tried_payment_card
# 3          66     29            deposited_money_account_cash
# 4          52     26             charged_fee_withdrawal_cash
# 5          50     22                  cancelled_payment_card
# 6          58     20                   waiting_time_transfer
# 7          54     20          charged_rate_exchange_currency
# 8          56     19                           need_pin_bank
# 9          20     19                    like_account_service
# 10         21     18               access_option_auto_system
# 11         59     16                sent_money_transfer_hour
# 12         34     16               help_problem_money_glitch
# 13         47     15                   activate_card_process
# 14         19     14                     tell_number_time_up
# 15         35     14                         use_card_reason
# 16         87     14             declined_money_card_payment
# 17         60     13                 want_money_account_bank
# 18         64     13            help_card_account_withdrawal
# 19         71     13                   shows_debit_statement
# 20         89     13                         work_card_store
# 21          8     13                        find_source_fund
# 22          6     13                      tell_currency_fiat
# 23         13     12                      explain_card_limit
# 24          0     12                   remember_passcode_app
# 25         55     11                           find_pin_card
# 26         73     11                       expires_card_cost
# 27         48     11                        expect_card_week
# 28         45     11                  declined_transfer_card
# 29          9     11                need_transaction_morning
# 30         62     11                 pending_withdrawal_cash
# 31         49     11                     think_rate_exchange
# 32         26     11       need_documentation_identity_check
# 33         70     10                use_atm_location_circuit
# 34         84     10                       help_cash_account
# 35         10     10            receive_payment_currency_usd
# 36         80     10                     charged_card_charge
# 37         39     10                receive_money_charge_fee
# 38          2     10               need_account_age_daughter
# 39         42     10                        left_phone_hotel
# 40         17     10                    need_up_verification
# 41         72      9                        receive_card_fee
# 42         77      9                      cancel_payment_app
# 43         83      9                         tell_money_card
# 44         46      9                           link_card_app
# 45         57      9                 delivered_card_tracking
# 46         76      9                    find_access_app_card
# 47         28      9             charged_fee_transfer_charge
# 48         75      9              transferred_money_transfer
# 49         14      9                  explain_transfer_error
# 50          4      8                         let_card_device
# 51         18      8             find_card_verification_code
# 52         29      8             accept_cheque_bank_transfer
# 53         37      8                          use_card_limit
# 54         36      8           explain_trouble_work_currency
# 55         15      7                         cancel_transfer
# 56         86      7                 stolen_step_card_police
# 57         43      7                       need_card_account
# 58         23      7  verified_account_identity_verification
# 59         11      7                     use_visa_mastercard
# 60         63      7                    shows_money_transfer
# 61         68      7             charged_1_pound_transaction
# 62         25      6             want_account_friend_payment
# 63         27      6               charged_fee_transfer_bank
# 64         31      6                   change_address_spouse
# 65         32      6                 letting_identity_system
# 66         67      6                charged_transaction_time
# 67         81      6               need_source_money_morning
# 68         88      6                               help_card
# 69          7      6       allowed_transfer_beneficiary_rule
# 70         38      6                        use_app_currency
# 71         40      6                 operate_service_country
# 72         41      6         deal_business_currency_exchange
# 73         12      6                        visa_credit_card
# 74         53      6                given_rate_exchange_item
# 75         24      5              accept_card_security_place
# 76          1      5            tried_plug_contactless_today
# 77         85      5                  stolen_card_permission
# 78         16      5                           need_transfer
# 79         51      5                         got_100_machine
# 80         33      5                                    gone
# 81         79      5                        charged_fee_card
# 82         78      5                  tried_card_transaction
# 83         74      5                  noticed_charge_account
# 84         30      5                       charged_bank_card
# 85         69      5                   explain_fee_statement
# 86          3      5                transfer_transfer_charge
# 87          5      5                        working_card_car
# 88         61      5                               card_list
# 89         82      4             m_transaction_account_money
# 90         44      4              use_money_account_interval
#
#                                  top_ground_category  top_cat_count  \
# 0                               card_about_to_expire              6
# 1                              Refund_not_showing_up             24
# 2                               pending_card_payment             19
# 3   balance_not_updated_after_cheque_or_cash_deposit             17
# 4                             cash_withdrawal_charge             23
# 5                             reverted_card_payment?             13
# 6                                   pending_transfer              8
# 7                                      exchange_rate              9
# 8                                         change_pin             11
# 9                                  terminate_account             13
# 10                                  automatic_top_up             14
# 11                transfer_not_received_by_recipient              6
# 12                                   top_up_reverted              6
# 13                                  activate_my_card             13
# 14                                     top_up_limits              7
# 15                             top_up_by_card_charge              4
# 16                             declined_card_payment              8
# 17                             transfer_into_account              7
# 18                    cash_withdrawal_not_recognised             11
# 19               direct_debit_payment_not_recognised             12
# 20                                  card_not_working              8
# 21                            verify_source_of_funds             13
# 22                             fiat_currency_support             10
# 23                       get_disposable_virtual_card              4
# 24                                passcode_forgotten             12
# 25                                 get_physical_card              8
# 26                              card_about_to_expire              8
# 27                            card_delivery_estimate              6
# 28                                 declined_transfer             10
# 29                                   cancel_transfer              8
# 30                           pending_cash_withdrawal             11
# 31           wrong_exchange_rate_for_cash_withdrawal              9
# 32                                verify_my_identity              8
# 33                                       atm_support             10
# 34                     wrong_amount_of_cash_received              7
# 35                                   receiving_money              6
# 36                          card_payment_fee_charged              5
# 37                                   receiving_money              4
# 38                                         age_limit             10
# 39                              lost_or_stolen_phone              9
# 40                                     verify_top_up             10
# 41                               order_physical_card              9
# 42                       card_payment_not_recognised              4
# 43                          declined_cash_withdrawal              6
# 44                                      card_linking              8
# 45                               order_physical_card              6
# 46                       card_payment_not_recognised              6
# 47                              transfer_fee_charged              6
# 48                transfer_not_received_by_recipient              3
# 49                                   failed_transfer              6
# 50                              getting_virtual_card              3
# 51                                     verify_top_up              8
# 52                          top_up_by_cash_or_cheque              6
# 53                       get_disposable_virtual_card              7
# 54                           apple_pay_or_google_pay              7
# 55                                   cancel_transfer              7
# 56                               lost_or_stolen_card              3
# 57                            disposable_card_limits              4
# 58                               why_verify_identity              4
# 59                                visa_or_mastercard              7
# 60                                   transfer_timing              2
# 61                         extra_charge_on_statement              7
# 62                                topping_up_by_card              3
# 63                              transfer_fee_charged              6
# 64                             edit_personal_details              6
# 65                         unable_to_verify_identity              6
# 66                         transaction_charged_twice              6
# 67                            verify_source_of_funds              4
# 68                               lost_or_stolen_card              4
# 69                           beneficiary_not_allowed              6
# 70                                  exchange_via_app              3
# 71                                   country_support              6
# 72                             fiat_currency_support              5
# 73                                visa_or_mastercard              5
# 74                  card_payment_wrong_exchange_rate              6
# 75                                   card_acceptance              3
# 76                           contactless_not_working              4
# 77                                  compromised_card              3
# 78                                   transfer_timing              5
# 79                     wrong_amount_of_cash_received              5
# 80                                    pending_top_up              3
# 81                          card_payment_fee_charged              3
# 82                          declined_cash_withdrawal              4
# 83                         transaction_charged_twice              3
# 84                             top_up_by_card_charge              5
# 85                         extra_charge_on_statement              4
# 86                    top_up_by_bank_transfer_charge              5
# 87                          virtual_card_not_working              4
# 88                                   card_acceptance              4
# 89                            cash_withdrawal_charge              1
# 90                    supported_cards_and_currencies              2
#
#     perc_top_cat
# 0             10
# 1             51
# 2             59
# 3             59
# 4             88
# 5             59
# 6             40
# 7             45
# 8             58
# 9             68
# 10            78
# 11            38
# 12            38
# 13            87
# 14            50
# 15            29
# 16            57
# 17            54
# 18            85
# 19            92
# 20            62
# 21           100
# 22            77
# 23            33
# 24           100
# 25            73
# 26            73
# 27            55
# 28            91
# 29            73
# 30           100
# 31            82
# 32            73
# 33           100
# 34            70
# 35            60
# 36            50
# 37            40
# 38           100
# 39            90
# 40           100
# 41           100
# 42            44
# 43            67
# 44            89
# 45            67
# 46            67
# 47            67
# 48            33
# 49            67
# 50            38
# 51           100
# 52            75
# 53            88
# 54            88
# 55           100
# 56            43
# 57            57
# 58            57
# 59           100
# 60            29
# 61           100
# 62            50
# 63           100
# 64           100
# 65           100
# 66           100
# 67            67
# 68            67
# 69           100
# 70            50
# 71           100
# 72            83
# 73            83
# 74           100
# 75            60
# 76            80
# 77            60
# 78           100
# 79           100
# 80            60
# 81            60
# 82            80
# 83            60
# 84           100
# 85            80
# 86           100
# 87            80
# 88            80
# 89            25
# 90            50
